# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
# !python "/content/drive/MyDrive/TFM-Data-Science/modelos/cdil_cnn/train.py"
# Out:
# ════════════════════════════════════════════════════════════
#   CDIL CNN — Detección de Parkinson
#   Experimento : neurovoz_64_dropout0.2
#   Dataset     : neurovoz
#   Config      : nhid=64, ks=3, dropout=0.2
#   Entrenamiento: epochs=200, lr=0.001, batch=32
#   Dispositivo : cuda
#   Resultados  : /content/drive/MyDrive/TFM-Data-Science/modelos/cdil_cnn/results/neurovoz_64_dropout0.2
# ════════════════════════════════════════════════════════════
#
#   Muestras/audio : 10781  (0.489s @ 22050Hz)
#   Capas CDIL     : 8  (= min(floor(log2(10781)), 8))
#   Parámetros     : 87,490
#
# ────────────────────────────────────────────────────────────
#   FOLD 1 / 5
# ────────────────────────────────────────────────────────────
#     Sujetos → Train: 90  Test: 21
#     Audios  → Train: 363  Test: 91
#     Cargando audios...
#       363 audios  (Control=159, Parkinson=204)
#       91 audios  (Control=40, Parkinson=51)
#
#     Entrenando (200 épocas, log cada 10)...
# ...
