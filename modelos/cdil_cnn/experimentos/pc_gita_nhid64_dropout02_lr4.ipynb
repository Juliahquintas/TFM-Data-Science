# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
# !python "/content/drive/MyDrive/TFM-Data-Science/modelos/cdil_cnn/train.py"
# Out:
# ════════════════════════════════════════════════════════════
#   CDIL CNN — Detección de Parkinson
#   Experimento : pc_gita_nhid64_dropout02_lr4
#   Dataset     : pc-gita
#   Config      : nhid=64, ks=3, dropout=0.2
#   Entrenamiento: epochs=200, lr=0.0001, batch=32
#   Dispositivo : cuda
#   Resultados  : /content/drive/MyDrive/TFM-Data-Science/modelos/cdil_cnn/results/pc_gita_nhid64_dropout02_lr4
# ════════════════════════════════════════════════════════════
#
#   Muestras/audio : 10781  (0.489s @ 22050Hz)
#   Capas CDIL     : 13  (= min(floor(log2(10781)), 8))
#   Parámetros     : 149,570
#
# ────────────────────────────────────────────────────────────
#   FOLD 1 / 5
# ────────────────────────────────────────────────────────────
#     Sujetos → Train: 80  Test: 20
#     Audios  → Train: 480  Test: 120
#     Cargando audios...
#       480 audios  (Control=240, Parkinson=240)
#       120 audios  (Control=60, Parkinson=60)
#
#     Entrenando (200 épocas, log cada 10)...
#       Epoch [  1/200]  Train — loss: 1.0265  acc: 47.9%
#       Epoch [ 10/200]  Train — loss: 0.7057  acc: 49.8%
#       Epoch [ 20/200]  Train — loss: 0.6825  acc: 57.1%
#       Epoch [ 30/200]  Train — loss: 0.6693  acc: 59.8%
#       Epoch [ 40/200]  Train — loss: 0.6521  acc: 59.6%
#       Epoch [ 50/200]  Train — loss: 0.6370  acc: 61.0%
#       Epoch [ 60/200]  Train — loss: 0.6082  acc: 65.8%
#       Epoch [ 70/200]  Train — loss: 0.5661  acc: 70.2%
#       Epoch [ 80/200]  Train — loss: 0.5398  acc: 72.9%
#       Epoch [ 90/200]  Train — loss: 0.5283  acc: 72.5%
#       Epoch [100/200]  Train — loss: 0.4992  acc: 76.5%
#       Epoch [110/200]  Train — loss: 0.4918  acc: 74.0%
#       Epoch [120/200]  Train — loss: 0.4502  acc: 78.8%
#       Epoch [130/200]  Train — loss: 0.3937  acc: 83.5%
#       Epoch [140/200]  Train — loss: 0.4119  acc: 79.4%
#       Epoch [150/200]  Train — loss: 0.3664  acc: 84.2%
#       Epoch [160/200]  Train — loss: 0.2978  acc: 87.1%
#       Epoch [170/200]  Train — loss: 0.2742  acc: 87.3%
#       Epoch [180/200]  Train — loss: 0.2489  acc: 89.6%
#       Epoch [190/200]  Train — loss: 0.2466  acc: 89.2%
#       Epoch [200/200]  Train — loss: 0.2218  acc: 90.8%
#
#       ──────────────────────────────────────────────────
#       Test Fold 1  →  Acc: 0.5583  |  Prec: 0.6129  |  Rec: 0.3167  |  Spec: 0.8000  |  F1: 0.4176  |  AUC: 0.5694
#       ──────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────
#   FOLD 2 / 5
# ────────────────────────────────────────────────────────────
#     Sujetos → Train: 80  Test: 20
#     Audios  → Train: 480  Test: 120
#     Cargando audios...
#       480 audios  (Control=240, Parkinson=240)
#       120 audios  (Control=60, Parkinson=60)
#
#     Entrenando (200 épocas, log cada 10)...
#       Epoch [  1/200]  Train — loss: 0.7512  acc: 49.4%
#       Epoch [ 10/200]  Train — loss: 0.6885  acc: 54.4%
#       Epoch [ 20/200]  Train — loss: 0.6830  acc: 59.6%
#       Epoch [ 30/200]  Train — loss: 0.6826  acc: 53.5%
#       Epoch [ 40/200]  Train — loss: 0.6546  acc: 60.0%
#       Epoch [ 50/200]  Train — loss: 0.6239  acc: 65.4%
#       Epoch [ 60/200]  Train — loss: 0.6038  acc: 65.6%
#       Epoch [ 70/200]  Train — loss: 0.5781  acc: 69.8%
#       Epoch [ 80/200]  Train — loss: 0.5374  acc: 72.1%
#       Epoch [ 90/200]  Train — loss: 0.5152  acc: 72.9%
#       Epoch [100/200]  Train — loss: 0.5523  acc: 69.8%
#       Epoch [110/200]  Train — loss: 0.4433  acc: 76.5%
#       Epoch [120/200]  Train — loss: 0.4524  acc: 79.8%
#       Epoch [130/200]  Train — loss: 0.4094  acc: 80.8%
#       Epoch [140/200]  Train — loss: 0.3632  acc: 83.8%
#       Epoch [150/200]  Train — loss: 0.3442  acc: 83.8%
#       Epoch [160/200]  Train — loss: 0.3086  acc: 86.9%
#       Epoch [170/200]  Train — loss: 0.3043  acc: 86.9%
#
#       ──────────────────────────────────────────────────
#       Test Fold 4  →  Acc: 0.6750  |  Prec: 0.7442  |  Rec: 0.5333  |  Spec: 0.8167  |  F1: 0.6214  |  AUC: 0.7578
#       ──────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────
#   FOLD 5 / 5
# ────────────────────────────────────────────────────────────
#     Sujetos → Train: 80  Test: 20
#     Audios  → Train: 480  Test: 120
#     Cargando audios...
#       480 audios  (Control=240, Parkinson=240)
#       120 audios  (Control=60, Parkinson=60)
#
#     Entrenando (200 épocas, log cada 10)...
#       Epoch [  1/200]  Train — loss: 2.6687  acc: 45.8%
#       Epoch [ 10/200]  Train — loss: 0.6934  acc: 49.6%
#       Epoch [ 20/200]  Train — loss: 0.6982  acc: 51.7%
#       Epoch [ 30/200]  Train — loss: 0.7069  acc: 47.5%
#       Epoch [ 40/200]  Train — loss: 0.6574  acc: 61.0%
#       Epoch [ 50/200]  Train — loss: 0.6285  acc: 62.5%
#       Epoch [ 60/200]  Train — loss: 0.6062  acc: 65.6%
#       Epoch [ 70/200]  Train — loss: 0.5879  acc: 66.5%
#       Epoch [ 80/200]  Train — loss: 0.5648  acc: 71.0%
#       Epoch [ 90/200]  Train — loss: 0.5495  acc: 72.5%
#       Epoch [100/200]  Train — loss: 0.5181  acc: 73.1%
#       Epoch [110/200]  Train — loss: 0.5765  acc: 70.4%
#       Epoch [120/200]  Train — loss: 0.5338  acc: 69.4%
#       Epoch [130/200]  Train — loss: 0.4748  acc: 75.6%
#       Epoch [140/200]  Train — loss: 0.4423  acc: 78.5%
#       Epoch [150/200]  Train — loss: 0.4045  acc: 80.0%
#       Epoch [160/200]  Train — loss: 0.3912  acc: 80.0%
#       Epoch [170/200]  Train — loss: 0.4211  acc: 78.1%
#       Epoch [180/200]  Train — loss: 0.3249  acc: 84.6%
#       Epoch [190/200]  Train — loss: 0.3702  acc: 82.9%
#       Epoch [200/200]  Train — loss: 0.3151  acc: 84.6%
#
#       ──────────────────────────────────────────────────
#       Test Fold 5  →  Acc: 0.5333  |  Prec: 0.6000  |  Rec: 0.2000  |  Spec: 0.8667  |  F1: 0.3000  |  AUC: 0.5981
#       ──────────────────────────────────────────────────
#
# ════════════════════════════════════════════════════════════
#   RESULTADOS FINALES — 5-Fold CV  [pc-gita]
# ════════════════════════════════════════════════════════════
#   Métrica             Media      ±Std        CV
#   ────────────────────────────────────────────────
#   Accuracy           0.6183    0.0701    0.1133
#   Precision          0.6507    0.0588    0.0904
#   Recall             0.4933    0.2317    0.4697
#   Specificity        0.7433    0.1188    0.1598
#   F1                 0.5386    0.1723    0.3199
#   Auc                0.6895    0.0979    0.1420
# ════════════════════════════════════════════════════════════
#
#   Detalle por fold:
#  fold  accuracy  precision  recall  specificity     f1    auc
#     1    0.5583     0.6129  0.3167       0.8000 0.4176 0.5694
#     2    0.6917     0.6716  0.7500       0.6333 0.7087 0.7789
#     3    0.6333     0.6250  0.6667       0.6000 0.6452 0.7433
#     4    0.6750     0.7442  0.5333       0.8167 0.6214 0.7578
#     5    0.5333     0.6000  0.2000       0.8667 0.3000 0.5981
#
#   ✓ Experimento registrado en: /content/drive/MyDrive/TFM-Data-Science/modelos/cdil_cnn/results/experiments_log.csv
#
#   ✓ Todos los resultados guardados en: /content/drive/MyDrive/TFM-Data-Science/modelos/cdil_cnn/results/pc_gita_nhid64_dropout02_lr4
#
#   Para comparar experimentos abre: /content/drive/MyDrive/TFM-Data-Science/modelos/cdil_cnn/results/experiments_log.csv
#
#   ¡Experimento completado!
