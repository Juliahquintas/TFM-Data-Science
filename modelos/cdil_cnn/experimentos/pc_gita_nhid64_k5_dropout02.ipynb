# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
# !python "/content/drive/MyDrive/TFM-Data-Science/modelos/cdil_cnn/train.py"
# Out:
# ════════════════════════════════════════════════════════════
#   CDIL CNN — Detección de Parkinson
#   Experimento : pc_gita_nhid64_k5_dropout02
#   Dataset     : pc-gita
#   Config      : nhid=64, ks=5, dropout=0.2
#   Entrenamiento: epochs=200, lr=0.001, batch=32
#   Dispositivo : cuda
#   Resultados  : /content/drive/.shortcut-targets-by-id/1QZ8puxSJXs-pZ_BYtb9LPDWGO0zl6vJm/TFM-Data-Science/modelos/cdil_cnn/results/pc_gita_nhid64_k5_dropout02
# ════════════════════════════════════════════════════════════
#
#   Muestras/audio : 10781  (0.489s @ 22050Hz)
#   Capas CDIL     : 8  (= min(floor(log2(10781)), 8))
#   Parámetros     : 144,962
#
# ────────────────────────────────────────────────────────────
#   FOLD 1 / 5
# ────────────────────────────────────────────────────────────
#     Sujetos → Train: 80  Test: 20
#     Audios  → Train: 480  Test: 120
#     Cargando audios...
#       480 audios  (Control=240, Parkinson=240)
#       120 audios  (Control=60, Parkinson=60)
#
#     Entrenando (200 épocas, log cada 10)...
#       Epoch [  1/200]  Train — loss: 1.1411  acc: 47.1%
#       Epoch [ 10/200]  Train — loss: 0.6944  acc: 47.7%
#       Epoch [ 20/200]  Train — loss: 0.6825  acc: 59.2%
#       Epoch [ 30/200]  Train — loss: 0.6355  acc: 62.5%
#       Epoch [ 40/200]  Train — loss: 0.5356  acc: 71.5%
#       Epoch [ 50/200]  Train — loss: 0.4983  acc: 75.0%
#       Epoch [ 60/200]  Train — loss: 0.3544  acc: 83.5%
#       Epoch [ 70/200]  Train — loss: 0.2696  acc: 89.4%
#       Epoch [ 80/200]  Train — loss: 0.1778  acc: 92.9%
#       Epoch [ 90/200]  Train — loss: 0.1430  acc: 94.2%
#       Epoch [100/200]  Train — loss: 0.0629  acc: 98.3%
#       Epoch [110/200]  Train — loss: 0.0655  acc: 97.3%
#       Epoch [120/200]  Train — loss: 0.0131  acc: 99.8%
#       Epoch [130/200]  Train — loss: 0.0755  acc: 97.5%
#       Epoch [140/200]  Train — loss: 0.0061  acc: 100.0%
#       Epoch [150/200]  Train — loss: 0.0107  acc: 100.0%
#       Epoch [160/200]  Train — loss: 0.0030  acc: 100.0%
#       Epoch [170/200]  Train — loss: 0.0013  acc: 100.0%
#       Epoch [180/200]  Train — loss: 0.0007  acc: 100.0%
#       Epoch [190/200]  Train — loss: 0.0005  acc: 100.0%
#       Epoch [200/200]  Train — loss: 0.0003  acc: 100.0%
#
#       ──────────────────────────────────────────────────
#       Test Fold 1  →  Acc: 0.4917  |  Prec: 0.4930  |  Rec: 0.5833  |  Spec: 0.4000  |  F1: 0.5344  |  AUC: 0.5171
#       ──────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────
#   FOLD 2 / 5
# ────────────────────────────────────────────────────────────
#     Sujetos → Train: 80  Test: 20
#     Audios  → Train: 480  Test: 120
#     Cargando audios...
#       480 audios  (Control=240, Parkinson=240)
#       120 audios  (Control=60, Parkinson=60)
#
#     Entrenando (200 épocas, log cada 10)...
#       Epoch [  1/200]  Train — loss: 1.1112  acc: 48.1%
#       Epoch [ 10/200]  Train — loss: 0.6943  acc: 49.6%
#       Epoch [ 20/200]  Train — loss: 0.6902  acc: 52.3%
#       Epoch [ 30/200]  Train — loss: 0.6448  acc: 63.1%
#       Epoch [ 40/200]  Train — loss: 0.5859  acc: 68.5%
#       Epoch [ 50/200]  Train — loss: 0.4949  acc: 75.6%
#       Epoch [ 60/200]  Train — loss: 0.3857  acc: 80.0%
#       Epoch [ 70/200]  Train — loss: 0.3271  acc: 85.4%
#       Epoch [ 80/200]  Train — loss: 0.2822  acc: 85.6%
#       Epoch [ 90/200]  Train — loss: 0.2277  acc: 88.1%
#       Epoch [100/200]  Train — loss: 0.2070  acc: 90.4%
#       Epoch [110/200]  Train — loss: 0.0821  acc: 98.5%
#       Epoch [120/200]  Train — loss: 0.0450  acc: 98.1%
#       Epoch [130/200]  Train — loss: 0.0076  acc: 100.0%
#       Epoch [140/200]  Train — loss: 0.0020  acc: 100.0%
#       Epoch [150/200]  Train — loss: 0.0009  acc: 100.0%
#       Epoch [160/200]  Train — loss: 0.0006  acc: 100.0%
#       Epoch [170/200]  Train — loss: 0.0003  acc: 100.0%
#       Epoch [180/200]  Train — loss: 0.0003  acc: 100.0%
#       Epoch [190/200]  Train — loss: 0.0002  acc: 100.0%
#       Epoch [200/200]  Train — loss: 0.0001  acc: 100.0%
#
#       ──────────────────────────────────────────────────
#       Test Fold 2  →  Acc: 0.7667  |  Prec: 0.8478  |  Rec: 0.6500  |  Spec: 0.8833  |  F1: 0.7358  |  AUC: 0.8121
#       ──────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────
#   FOLD 3 / 5
# ────────────────────────────────────────────────────────────
#     Sujetos → Train: 80  Test: 20
#     Audios  → Train: 480  Test: 120
#     Cargando audios...
#       480 audios  (Control=240, Parkinson=240)
#       120 audios  (Control=60, Parkinson=60)
#
#     Entrenando (200 épocas, log cada 10)...
#       Epoch [  1/200]  Train — loss: 0.9139  acc: 52.1%
#       Epoch [ 10/200]  Train — loss: 0.6957  acc: 50.4%
#       Epoch [ 20/200]  Train — loss: 0.6729  acc: 55.0%
#       Epoch [ 30/200]  Train — loss: 0.6165  acc: 63.3%
#       Epoch [ 40/200]  Train — loss: 0.5210  acc: 74.4%
#       Epoch [ 50/200]  Train — loss: 0.3992  acc: 80.6%
#       Epoch [ 60/200]  Train — loss: 0.2827  acc: 88.5%
#       Epoch [ 70/200]  Train — loss: 0.2917  acc: 88.1%
#       Epoch [ 80/200]  Train — loss: 0.1630  acc: 94.6%
#       Epoch [ 90/200]  Train — loss: 0.2251  acc: 87.7%
#       Epoch [100/200]  Train — loss: 0.0931  acc: 97.5%
#       Epoch [110/200]  Train — loss: 0.1456  acc: 94.4%
#       Epoch [120/200]  Train — loss: 0.0258  acc: 99.4%
#       Epoch [130/200]  Train — loss: 0.0134  acc: 99.6%
#       Epoch [140/200]  Train — loss: 0.0043  acc: 100.0%
#       Epoch [150/200]  Train — loss: 0.0115  acc: 99.6%
#       Epoch [160/200]  Train — loss: 0.0070  acc: 100.0%
#       Epoch [170/200]  Train — loss: 0.0026  acc: 100.0%
#       Epoch [180/200]  Train — loss: 0.0011  acc: 100.0%
#       Epoch [190/200]  Train — loss: 0.0006  acc: 100.0%
#       Epoch [200/200]  Train — loss: 0.0004  acc: 100.0%
#
#       ──────────────────────────────────────────────────
#       Test Fold 3  →  Acc: 0.6417  |  Prec: 0.6349  |  Rec: 0.6667  |  Spec: 0.6167  |  F1: 0.6504  |  AUC: 0.6629
#       ──────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────
#   FOLD 4 / 5
# ────────────────────────────────────────────────────────────
#     Sujetos → Train: 80  Test: 20
#     Audios  → Train: 480  Test: 120
#     Cargando audios...
#       480 audios  (Control=240, Parkinson=240)
#       120 audios  (Control=60, Parkinson=60)
#
#     Entrenando (200 épocas, log cada 10)...
#       Epoch [  1/200]  Train — loss: 0.9438  acc: 46.9%
