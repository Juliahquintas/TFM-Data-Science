# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import torch
torch.cuda.is_available()

# %%
# !python "/content/drive/MyDrive/TFM-Data-Science/modelos/cdil_cnn_sinValid/train.py"
