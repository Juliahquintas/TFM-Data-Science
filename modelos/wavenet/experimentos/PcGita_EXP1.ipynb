# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
# !python "/content/drive/MyDrive/TFM-Data-Science/modelos/wavenet/train.py"
# Out:
# ════════════════════════════════════════════════════════════
#   CDIL CNN — Detección de Parkinson
#   Experimento : pc_gita_True_NoCausal_32
#   Dataset     : pc-gita
#   Config      : nhid=32, ks=3, dropout=0.0
#   Entrenamiento: epochs=200, lr=0.001, batch=32
#   Dispositivo : cuda
#   Resultados  : /content/drive/MyDrive/TFM-Data-Science/modelos/wavenet/results/pc_gita_True_NoCausal_32
# ════════════════════════════════════════════════════════════
#
#   Muestras/audio : 10781  (0.489s @ 22050Hz)
#   Capas CDIL     : 8  (= min(floor(log2(10781)), 8))
#   Parámetros     : 44,354
#
# ────────────────────────────────────────────────────────────
#   FOLD 1 / 5
# ────────────────────────────────────────────────────────────
#     Sujetos → Train: 80  Test: 20
#     Audios  → Train: 480  Test: 120
#     Cargando audios...
#       480 audios  (Control=240, Parkinson=240)
#       120 audios  (Control=60, Parkinson=60)
#
#     Entrenando (200 épocas, log cada 10)...
# ...
