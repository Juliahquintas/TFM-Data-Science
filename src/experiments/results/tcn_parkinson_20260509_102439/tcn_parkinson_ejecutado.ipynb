# %% [markdown]
# # TCN Classifier — Clasificación de Audio Raw (Parkinson)
#
# Clasificación binaria **Control vs Patológicas** usando una **Temporal Convolutional Network (TCN)**
# con activación WaveNet (tanh × sigmoid) aplicada directamente sobre la forma de onda.
#
# ---
# ## ¿Qué es un TCN y cómo funciona?
#
# Un TCN es una red convolucional 1D con tres propiedades clave:
#
# | Propiedad | Detalle |
# |---|---|
# | **Causalidad** | Padding `causal`: el modelo sólo ve el pasado, nunca el futuro |
# | **Dilatación exponencial** | Cada bloque usa `dilation_rate = 2^k`, aumentando el campo receptivo sin más parámetros |
# | **Conexiones residuales** | `salida = entrada + f(entrada)`, como ResNet, facilita el entrenamiento profundo |
#
# ### Activación WaveNet (gated activation)
# ```
# gate = tanh(Conv1D_tanh(x))  ×  sigmoid(Conv1D_sigm(x))
# ```
# - La rama **tanh** modula el *contenido* (valores entre −1 y 1)
# - La rama **sigmoid** actúa como *puerta* (valores entre 0 y 1, controla cuánta información pasa)
# - Permite al modelo aprender patrones temporales complejos similares a una LSTM, pero paralelizable.
#
# ### Campo receptivo efectivo
# ```
# RF = 1 + (kernel_size − 1) × Σ(dilations) × nb_stacks
# ```
# Con `kernel_size=3, dilations=[1,2,4,8,16,32], nb_stacks=1`:
# ```
# RF = 1 + 2 × 63 × 1 = 127 muestras ≈ 7.9 ms @ 16 kHz
# ```
# Con `nb_stacks=2` → RF = 253 muestras ≈ 15.8 ms.
#
# ### Arquitectura completa
# ```
# Audio (8000,)
#   → Reshape (8000, 1)
#   → Conv1D 1×1  [proyección: 1 → nb_filters canales]
#   → Bloque residual (dilation=1)   ──► skip_1
#   → Bloque residual (dilation=2)   ──► skip_2
#   → Bloque residual (dilation=4)   ──► skip_3
#   → ...                             ...
#   → Add(skip_1, skip_2, ...) → ReLU
#   → GlobalAvgPool + GlobalMaxPool → Concat
#   → Dense(32, relu) → Dropout
#   → Dense(2, softmax)  [Control | Patológicas]
# ```
#
# - **Modelo**: `src/models/TCNClassifier.py`
# - **Splits**: Subject-wise K-Fold desde `data_splits.json`

# %%
import os
import sys
import json
import numpy as np
import librosa
from pathlib import Path
from tqdm import tqdm

import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import (
    classification_report, confusion_matrix, roc_auc_score,
    accuracy_score, ConfusionMatrixDisplay, RocCurveDisplay
)
import matplotlib.pyplot as plt

# ── Detectar raíz del proyecto ────────────────────────────────────────────────
PROJECT_ROOT = Path.cwd()
while not (PROJECT_ROOT / 'data').exists() and PROJECT_ROOT != PROJECT_ROOT.parent:
    PROJECT_ROOT = PROJECT_ROOT.parent
print(f"PROJECT_ROOT: {PROJECT_ROOT}")

# ── Importar TCNClassifier ────────────────────────────────────────────────────
sys.path.insert(0, str(PROJECT_ROOT / 'src' / 'models'))
from TCNClassifier import TCNClassifier

print(f"TensorFlow: {tf.__version__}")
print(f"GPU disponible: {tf.config.list_physical_devices('GPU')}")
# Out:
# 2026-05-09 10:24:48.706777: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-09 10:24:49.153920: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-05-09 10:24:49.154008: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-05-09 10:24:49.259247: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# PROJECT_ROOT: /media/beegfs/home/y222/y222732/DeepLearningChallenge/TFM-Data-Science
# TensorFlow: 2.15.1
# GPU disponible: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## 1. Hiperparámetros

# %%
TARGET_SR      = 8000
TARGET_SAMPLES = 4000   # 0.5 s

NB_FILTERS   = 64
KERNEL_SIZE  = 3
DILATIONS    = [1, 2, 4, 8, 16, 32, 64, 128]  # RF = 1 + 2×255 = 511 muestras ≈ 64 ms
NB_STACKS    = 2                                # ×2 → RF ≈ 128 ms
# Con nb_stacks=2: RF efectivo = 1021 muestras ≈ 128 ms @ 8 kHz
DROPOUT_RATE = 0.2   # más dropout, menos datos
DENSE_UNITS  = 32
BATCH_SIZE   = 16    #

# %%
# ============================================================
#  HIPERPARÁMETROS — Modifica aquí para experimentar
# ============================================================
DATASET_NAME = 'pc-gita'   # 'neurovoz' o 'pc-gita'
FOLD_IDX     = 4            # Fold a evaluar (0..K-1)

# # ── Audio ────────────────────────────────────────────────────
# ORIGINAL_SR    = 22050   # SR de los audios procesados en disco
# TARGET_SR      = 16000   # SR al que resamplea el modelo
# TARGET_SAMPLES = 8000    # Muestras de entrada (8000 = 0.5 s @ 16 kHz)
# #   ↑ Cambia a 16000 para 1 s, 4000 para 0.25 s, etc.
# #   El campo receptivo del TCN es independiente de esta longitud.

# # ── Arquitectura TCN ─────────────────────────────────────────
# # kernel_size=3 + dilations=[1,2,4,8,16,32] → RF ≈ 127 muestras (7.9 ms)
# # Aumentar nb_stacks o añadir más dilaciones amplía el campo receptivo.
# NB_FILTERS   = 64
# KERNEL_SIZE  = 3
# DILATIONS    = [1, 2, 4, 8, 16, 32]   # dilataciones exponenciales
# NB_STACKS    = 1                       # repeticiones del bloque de dilaciones
# DROPOUT_RATE = 0.1
# DENSE_UNITS  = 32

# ── Entrenamiento ────────────────────────────────────────────
EPOCHS     = 50
BATCH_SIZE = 32
OPTIMIZER  = 'adam'
NUM_CLASSES = 2   # Control (0) vs Patológicas (1)

# ── Rutas ─────────────────────────────────────────────────────
DATA_DIR    = PROJECT_ROOT / 'data' / 'processed'
SPLITS_FILE = PROJECT_ROOT / 'data' / 'data_splits.json'

# ── Cálculo del campo receptivo ──────────────────────────────
RF = 1 + (KERNEL_SIZE - 1) * sum(DILATIONS) * NB_STACKS
RF_ms = RF / TARGET_SR * 1000

DATASET_NAME = 'pc-gita'

print("Configuración:")
print(f"  Dataset:          {DATASET_NAME}")
# print(f"  SR original:      {ORIGINAL_SR} Hz")
print(f"  SR del modelo:    {TARGET_SR} Hz")
print(f"  Target samples:   {TARGET_SAMPLES} ({TARGET_SAMPLES/TARGET_SR*1000:.0f} ms)")
print(f"  input_shape:      ({TARGET_SAMPLES},)")
print(f"  TCN nb_filters:   {NB_FILTERS}")
print(f"  TCN kernel_size:  {KERNEL_SIZE}")
print(f"  TCN dilations:    {DILATIONS}")
print(f"  TCN nb_stacks:    {NB_STACKS}")
print(f"  Campo receptivo:  {RF} muestras ≈ {RF_ms:.1f} ms @ {TARGET_SR} Hz")
# Out:
# Configuración:
#   Dataset:          pc-gita
#   SR del modelo:    8000 Hz
#   Target samples:   4000 (500 ms)
#   input_shape:      (4000,)
#   TCN nb_filters:   64
#   TCN kernel_size:  3
#   TCN dilations:    [1, 2, 4, 8, 16, 32, 64, 128]
#   TCN nb_stacks:    2
#   Campo receptivo:  1021 muestras ≈ 127.6 ms @ 8000 Hz

# %% [markdown]
# ## 2. Carga de Splits y Audio
#
# Se reutiliza exactamente la misma lógica de carga que en `wavenet.ipynb`:
# - Resample de 22050 Hz → 16000 Hz con `librosa.load(sr=TARGET_SR)`
# - Pad con ceros o crop a `TARGET_SAMPLES` muestras
# - Etiqueta: `1` si `'Patologicas'` aparece en la ruta, `0` si no

# %%
# Cargar JSON de splits
with open(SPLITS_FILE, 'r') as f:
    all_splits = json.load(f)

folds = all_splits[DATASET_NAME]
K     = all_splits['metadata']['K_folds']
print(f"Dataset: {DATASET_NAME} | K={K} folds disponibles")
# Out:
# Dataset: pc-gita | K=5 folds disponibles

# %%
def load_audio_files(file_list, data_dir, target_sr, target_samples):
    """
    Carga, resamplea y normaliza una lista de audios.

    Returns
    -------
    X : np.ndarray, shape (N, target_samples)   — formas de onda
    y : np.ndarray, shape (N,)                  — etiquetas (0/1)
    """
    waveforms, labels = [], []
    skipped = 0

    for rel_path in tqdm(file_list, desc='Cargando audios', leave=False):
        rel_path_clean = rel_path.replace('\\', os.sep).replace('/', os.sep)
        full_path = data_dir / rel_path_clean

        if not full_path.exists():
            skipped += 1
            continue

        # Carga con resample al vuelo
        y_audio, _ = librosa.load(full_path, sr=target_sr)

        # Pad o crop
        if len(y_audio) >= target_samples:
            y_audio = y_audio[:target_samples]
        else:
            y_audio = np.pad(y_audio, (0, target_samples - len(y_audio)))

        waveforms.append(y_audio)
        labels.append(1 if 'Patologicas' in rel_path else 0)

    if skipped:
        print(f"  ⚠ {skipped} archivos no encontrados y omitidos")

    return np.array(waveforms, dtype=np.float32), np.array(labels, dtype=np.int32)


def load_fold_data(fold_dict, data_dir, target_sr, target_samples):
    """Carga train, val y test de un fold."""
    print("Cargando TRAIN...")
    X_tr, y_tr = load_audio_files(fold_dict['train_files'], data_dir, target_sr, target_samples)
    print(f"  X_train: {X_tr.shape}  (HC={np.sum(y_tr==0)}, PA={np.sum(y_tr==1)})")

    print("Cargando VAL...")
    X_v, y_v = load_audio_files(fold_dict['val_files'], data_dir, target_sr, target_samples)
    print(f"  X_val:   {X_v.shape}  (HC={np.sum(y_v==0)}, PA={np.sum(y_v==1)})")

    print("Cargando TEST...")
    X_te, y_te = load_audio_files(fold_dict['test_files'], data_dir, target_sr, target_samples)
    print(f"  X_test:  {X_te.shape}  (HC={np.sum(y_te==0)}, PA={np.sum(y_te==1)})")

    return X_tr, y_tr, X_v, y_v, X_te, y_te

# %%
# Cargar el fold seleccionado
fold_data = folds[FOLD_IDX]
X_train, y_train_raw, X_val, y_val_raw, X_test, y_test_raw = load_fold_data(
    fold_data, DATA_DIR, TARGET_SR, TARGET_SAMPLES
)

# One-hot encoding para Keras (loss=categorical_crossentropy)
y_train = to_categorical(y_train_raw, NUM_CLASSES)
y_val   = to_categorical(y_val_raw,   NUM_CLASSES)
# y_test se deja en entero para las métricas sklearn

print(f"\nShapes finales:")
print(f"  X_train: {X_train.shape}  y_train: {y_train.shape}")
print(f"  X_val:   {X_val.shape}    y_val:   {y_val.shape}")
print(f"  X_test:  {X_test.shape}   y_test:  {y_test_raw.shape}")
# Out:
# Cargando TRAIN...
#   X_train: (360, 4000)  (HC=180, PA=180)
# Cargando VAL...
#   X_val:   (120, 4000)  (HC=60, PA=60)
# Cargando TEST...
#   X_test:  (120, 4000)  (HC=60, PA=60)
#
# Shapes finales:
#   X_train: (360, 4000)  y_train: (360, 2)
#   X_val:   (120, 4000)    y_val:   (120, 2)
#   X_test:  (120, 4000)   y_test:  (120,)

# %% [markdown]
# ## 3. Construir el Modelo TCN
#
# > **¿Por qué no necesitamos una capa Embedding?**
# > En el documento original, el TCN procesaba *texto* (secuencias de índices de palabras)
# > que primero se proyectaban a un espacio vectorial con `Embedding`.
# > Aquí la entrada ya es una señal continua (forma de onda), así que la primera capa
# > es directamente una `Conv1D 1×1` que proyecta 1 canal → `nb_filters` canales.

# %%
clf = TCNClassifier(
    input_shape  = (TARGET_SAMPLES,),
    n_classes    = NUM_CLASSES,
    nb_filters   = NB_FILTERS,
    kernel_size  = KERNEL_SIZE,
    dilations    = DILATIONS,
    nb_stacks    = NB_STACKS,
    dropout_rate = DROPOUT_RATE,
    dense_units  = DENSE_UNITS,
    padding      = 'causal',
    name         = 'tcn_parkinson',
)

print(clf.receptive_field_info())
clf.model.summary()
# Out:
# 2026-05-09 10:25:07.537797: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 38374 MB memory:  -> device: 0, name: NVIDIA A100-PCIE-40GB, pci bus id: 0000:06:00.0, compute capability: 8.0
# Campo receptivo: 1021 muestras ≈ 63.8 ms @ 16 kHz
# Model: "tcn_parkinson"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  audio_input (InputLayer)    [(None, 4000)]               0         []
#
#  reshape_input (Reshape)     (None, 4000, 1)              0         ['audio_input[0][0]']
#
#  tcn_parkinson_input_projec  (None, 4000, 64)             128       ['reshape_input[0][0]']
#  tion (Conv1D)
#
#  tcn_parkinson_s0_dilated_c  (None, 4000, 64)             12352     ['tcn_parkinson_input_projecti
#  onv_1_tanh (Conv1D)                                                on[0][0]']
#
#  tcn_parkinson_s0_dilated_c  (None, 4000, 64)             12352     ['tcn_parkinson_input_projecti
#  onv_1_sigm (Conv1D)                                                on[0][0]']
#
#  activation (Activation)     (None, 4000, 64)             0         ['tcn_parkinson_s0_dilated_con
#                                                                     v_1_tanh[0][0]']
#
#  activation_1 (Activation)   (None, 4000, 64)             0         ['tcn_parkinson_s0_dilated_con
#                                                                     v_1_sigm[0][0]']
#
#  multiply (Multiply)         (None, 4000, 64)             0         ['activation[0][0]',
#                                                                      'activation_1[0][0]']
#
#  tcn_parkinson_s0_dropout_1  (None, 4000, 64)             0         ['multiply[0][0]']
#   (SpatialDropout1D)
#
#  tcn_parkinson_s0_skip_1 (C  (None, 4000, 64)             4160      ['tcn_parkinson_s0_dropout_1[0
#  onv1D)                                                             ][0]']
#
#  tcn_parkinson_s0_residual_  (None, 4000, 64)             0         ['tcn_parkinson_input_projecti
#  1 (Add)                                                            on[0][0]',
#                                                                      'tcn_parkinson_s0_skip_1[0][0
#                                                                     ]']
#
#  tcn_parkinson_s0_dilated_c  (None, 4000, 64)             12352     ['tcn_parkinson_s0_residual_1[
#  onv_2_tanh (Conv1D)                                                0][0]']
#
#  tcn_parkinson_s0_dilated_c  (None, 4000, 64)             12352     ['tcn_parkinson_s0_residual_1[
#  onv_2_sigm (Conv1D)                                                0][0]']
#
#  activation_2 (Activation)   (None, 4000, 64)             0         ['tcn_parkinson_s0_dilated_con
#                                                                     v_2_tanh[0][0]']
#
#  activation_3 (Activation)   (None, 4000, 64)             0         ['tcn_parkinson_s0_dilated_con
#                                                                     v_2_sigm[0][0]']
#
#  multiply_1 (Multiply)       (None, 4000, 64)             0         ['activation_2[0][0]',
#                                                                      'activation_3[0][0]']
#
#  tcn_parkinson_s0_dropout_2  (None, 4000, 64)             0         ['multiply_1[0][0]']
#   (SpatialDropout1D)
#
#  tcn_parkinson_s0_skip_2 (C  (None, 4000, 64)             4160      ['tcn_parkinson_s0_dropout_2[0
#  onv1D)                                                             ][0]']
#
#  tcn_parkinson_s0_residual_  (None, 4000, 64)             0         ['tcn_parkinson_s0_residual_1[
#  2 (Add)                                                            0][0]',
#                                                                      'tcn_parkinson_s0_skip_2[0][0
#                                                                     ]']
#
#  tcn_parkinson_s0_dilated_c  (None, 4000, 64)             12352     ['tcn_parkinson_s0_residual_2[
#  onv_4_tanh (Conv1D)                                                0][0]']
#
#  tcn_parkinson_s0_dilated_c  (None, 4000, 64)             12352     ['tcn_parkinson_s0_residual_2[
#  onv_4_sigm (Conv1D)                                                0][0]']
#
#  activation_4 (Activation)   (None, 4000, 64)             0         ['tcn_parkinson_s0_dilated_con
#                                                                     v_4_tanh[0][0]']
#
#  activation_5 (Activation)   (None, 4000, 64)             0         ['tcn_parkinson_s0_dilated_con
#                                                                     v_4_sigm[0][0]']
#
#  multiply_2 (Multiply)       (None, 4000, 64)             0         ['activation_4[0][0]',
#                                                                      'activation_5[0][0]']
#
#  tcn_parkinson_s0_dropout_4  (None, 4000, 64)             0         ['multiply_2[0][0]']
#   (SpatialDropout1D)
#
#  tcn_parkinson_s0_skip_4 (C  (None, 4000, 64)             4160      ['tcn_parkinson_s0_dropout_4[0
#  onv1D)                                                             ][0]']
#
#  tcn_parkinson_s0_residual_  (None, 4000, 64)             0         ['tcn_parkinson_s0_residual_2[
#  4 (Add)                                                            0][0]',
#                                                                      'tcn_parkinson_s0_skip_4[0][0
#                                                                     ]']
#
#  tcn_parkinson_s0_dilated_c  (None, 4000, 64)             12352     ['tcn_parkinson_s0_residual_4[
#  onv_8_tanh (Conv1D)                                                0][0]']
#
#  tcn_parkinson_s0_dilated_c  (None, 4000, 64)             12352     ['tcn_parkinson_s0_residual_4[
#  onv_8_sigm (Conv1D)                                                0][0]']
#
#  activation_6 (Activation)   (None, 4000, 64)             0         ['tcn_parkinson_s0_dilated_con
#                                                                     v_8_tanh[0][0]']
#
#  activation_7 (Activation)   (None, 4000, 64)             0         ['tcn_parkinson_s0_dilated_con
#                                                                     v_8_sigm[0][0]']
#
#  multiply_3 (Multiply)       (None, 4000, 64)             0         ['activation_6[0][0]',
#                                                                      'activation_7[0][0]']
#
#  tcn_parkinson_s0_dropout_8  (None, 4000, 64)             0         ['multiply_3[0][0]']
#   (SpatialDropout1D)
#
#  tcn_parkinson_s0_skip_8 (C  (None, 4000, 64)             4160      ['tcn_parkinson_s0_dropout_8[0
#  onv1D)                                                             ][0]']
#
#  tcn_parkinson_s0_residual_  (None, 4000, 64)             0         ['tcn_parkinson_s0_residual_4[
#  8 (Add)                                                            0][0]',
#                                                                      'tcn_parkinson_s0_skip_8[0][0
#                                                                     ]']
#
#  tcn_parkinson_s0_dilated_c  (None, 4000, 64)             12352     ['tcn_parkinson_s0_residual_8[
#  onv_16_tanh (Conv1D)                                               0][0]']
#
#  tcn_parkinson_s0_dilated_c  (None, 4000, 64)             12352     ['tcn_parkinson_s0_residual_8[
#  onv_16_sigm (Conv1D)                                               0][0]']
#
#  activation_8 (Activation)   (None, 4000, 64)             0         ['tcn_parkinson_s0_dilated_con
#                                                                     v_16_tanh[0][0]']
#
#  activation_9 (Activation)   (None, 4000, 64)             0         ['tcn_parkinson_s0_dilated_con
#                                                                     v_16_sigm[0][0]']
#
#  multiply_4 (Multiply)       (None, 4000, 64)             0         ['activation_8[0][0]',
#                                                                      'activation_9[0][0]']
#
#  tcn_parkinson_s0_dropout_1  (None, 4000, 64)             0         ['multiply_4[0][0]']
#  6 (SpatialDropout1D)
#
#  tcn_parkinson_s0_skip_16 (  (None, 4000, 64)             4160      ['tcn_parkinson_s0_dropout_16[
#  Conv1D)                                                            0][0]']
#
#  tcn_parkinson_s0_residual_  (None, 4000, 64)             0         ['tcn_parkinson_s0_residual_8[
#  16 (Add)                                                           0][0]',
#                                                                      'tcn_parkinson_s0_skip_16[0][
#                                                                     0]']
#
#  tcn_parkinson_s0_dilated_c  (None, 4000, 64)             12352     ['tcn_parkinson_s0_residual_16
#  onv_32_tanh (Conv1D)                                               [0][0]']
#
#  tcn_parkinson_s0_dilated_c  (None, 4000, 64)             12352     ['tcn_parkinson_s0_residual_16
#  onv_32_sigm (Conv1D)                                               [0][0]']
#
#  activation_10 (Activation)  (None, 4000, 64)             0         ['tcn_parkinson_s0_dilated_con
#                                                                     v_32_tanh[0][0]']
#
#  activation_11 (Activation)  (None, 4000, 64)             0         ['tcn_parkinson_s0_dilated_con
#                                                                     v_32_sigm[0][0]']
#
#  multiply_5 (Multiply)       (None, 4000, 64)             0         ['activation_10[0][0]',
#                                                                      'activation_11[0][0]']
#
#  tcn_parkinson_s0_dropout_3  (None, 4000, 64)             0         ['multiply_5[0][0]']
#  2 (SpatialDropout1D)
#
#  tcn_parkinson_s0_skip_32 (  (None, 4000, 64)             4160      ['tcn_parkinson_s0_dropout_32[
#  Conv1D)                                                            0][0]']
#
#  tcn_parkinson_s0_residual_  (None, 4000, 64)             0         ['tcn_parkinson_s0_residual_16
#  32 (Add)                                                           [0][0]',
#                                                                      'tcn_parkinson_s0_skip_32[0][
#                                                                     0]']
#
#  tcn_parkinson_s0_dilated_c  (None, 4000, 64)             12352     ['tcn_parkinson_s0_residual_32
#  onv_64_tanh (Conv1D)                                               [0][0]']
#
#  tcn_parkinson_s0_dilated_c  (None, 4000, 64)             12352     ['tcn_parkinson_s0_residual_32
#  onv_64_sigm (Conv1D)                                               [0][0]']
#
#  activation_12 (Activation)  (None, 4000, 64)             0         ['tcn_parkinson_s0_dilated_con
#                                                                     v_64_tanh[0][0]']
#
#  activation_13 (Activation)  (None, 4000, 64)             0         ['tcn_parkinson_s0_dilated_con
#                                                                     v_64_sigm[0][0]']
#
#  multiply_6 (Multiply)       (None, 4000, 64)             0         ['activation_12[0][0]',
#                                                                      'activation_13[0][0]']
#
#  tcn_parkinson_s0_dropout_6  (None, 4000, 64)             0         ['multiply_6[0][0]']
#  4 (SpatialDropout1D)
#
#  tcn_parkinson_s0_skip_64 (  (None, 4000, 64)             4160      ['tcn_parkinson_s0_dropout_64[
#  Conv1D)                                                            0][0]']
#
#  tcn_parkinson_s0_residual_  (None, 4000, 64)             0         ['tcn_parkinson_s0_residual_32
#  64 (Add)                                                           [0][0]',
#                                                                      'tcn_parkinson_s0_skip_64[0][
#                                                                     0]']
#
#  tcn_parkinson_s0_dilated_c  (None, 4000, 64)             12352     ['tcn_parkinson_s0_residual_64
#  onv_128_tanh (Conv1D)                                              [0][0]']
#
#  tcn_parkinson_s0_dilated_c  (None, 4000, 64)             12352     ['tcn_parkinson_s0_residual_64
#  onv_128_sigm (Conv1D)                                              [0][0]']
#
#  activation_14 (Activation)  (None, 4000, 64)             0         ['tcn_parkinson_s0_dilated_con
#                                                                     v_128_tanh[0][0]']
#
#  activation_15 (Activation)  (None, 4000, 64)             0         ['tcn_parkinson_s0_dilated_con
#                                                                     v_128_sigm[0][0]']
#
#  multiply_7 (Multiply)       (None, 4000, 64)             0         ['activation_14[0][0]',
#                                                                      'activation_15[0][0]']
#
#  tcn_parkinson_s0_dropout_1  (None, 4000, 64)             0         ['multiply_7[0][0]']
#  28 (SpatialDropout1D)
#
#  tcn_parkinson_s0_skip_128   (None, 4000, 64)             4160      ['tcn_parkinson_s0_dropout_128
#  (Conv1D)                                                           [0][0]']
#
#  tcn_parkinson_s0_residual_  (None, 4000, 64)             0         ['tcn_parkinson_s0_residual_64
#  128 (Add)                                                          [0][0]',
#                                                                      'tcn_parkinson_s0_skip_128[0]
#                                                                     [0]']
#
#  tcn_parkinson_s1_dilated_c  (None, 4000, 64)             12352     ['tcn_parkinson_s0_residual_12
#  onv_1_tanh (Conv1D)                                                8[0][0]']
#
#  tcn_parkinson_s1_dilated_c  (None, 4000, 64)             12352     ['tcn_parkinson_s0_residual_12
#  onv_1_sigm (Conv1D)                                                8[0][0]']
#
#  activation_16 (Activation)  (None, 4000, 64)             0         ['tcn_parkinson_s1_dilated_con
#                                                                     v_1_tanh[0][0]']
#
#  activation_17 (Activation)  (None, 4000, 64)             0         ['tcn_parkinson_s1_dilated_con
#                                                                     v_1_sigm[0][0]']
#
#  multiply_8 (Multiply)       (None, 4000, 64)             0         ['activation_16[0][0]',
#                                                                      'activation_17[0][0]']
#
#  tcn_parkinson_s1_dropout_1  (None, 4000, 64)             0         ['multiply_8[0][0]']
#   (SpatialDropout1D)
#
#  tcn_parkinson_s1_skip_1 (C  (None, 4000, 64)             4160      ['tcn_parkinson_s1_dropout_1[0
#  onv1D)                                                             ][0]']
#
#  tcn_parkinson_s1_residual_  (None, 4000, 64)             0         ['tcn_parkinson_s0_residual_12
#  1 (Add)                                                            8[0][0]',
#                                                                      'tcn_parkinson_s1_skip_1[0][0
#                                                                     ]']
#
#  tcn_parkinson_s1_dilated_c  (None, 4000, 64)             12352     ['tcn_parkinson_s1_residual_1[
#  onv_2_tanh (Conv1D)                                                0][0]']
#
#  tcn_parkinson_s1_dilated_c  (None, 4000, 64)             12352     ['tcn_parkinson_s1_residual_1[
#  onv_2_sigm (Conv1D)                                                0][0]']
#
#  activation_18 (Activation)  (None, 4000, 64)             0         ['tcn_parkinson_s1_dilated_con
#                                                                     v_2_tanh[0][0]']
#
#  activation_19 (Activation)  (None, 4000, 64)             0         ['tcn_parkinson_s1_dilated_con
#                                                                     v_2_sigm[0][0]']
#
#  multiply_9 (Multiply)       (None, 4000, 64)             0         ['activation_18[0][0]',
#                                                                      'activation_19[0][0]']
#
#  tcn_parkinson_s1_dropout_2  (None, 4000, 64)             0         ['multiply_9[0][0]']
#   (SpatialDropout1D)
#
#  tcn_parkinson_s1_skip_2 (C  (None, 4000, 64)             4160      ['tcn_parkinson_s1_dropout_2[0
#  onv1D)                                                             ][0]']
#
#  tcn_parkinson_s1_residual_  (None, 4000, 64)             0         ['tcn_parkinson_s1_residual_1[
#  2 (Add)                                                            0][0]',
#                                                                      'tcn_parkinson_s1_skip_2[0][0
#                                                                     ]']
#
#  tcn_parkinson_s1_dilated_c  (None, 4000, 64)             12352     ['tcn_parkinson_s1_residual_2[
#  onv_4_tanh (Conv1D)                                                0][0]']
#
#  tcn_parkinson_s1_dilated_c  (None, 4000, 64)             12352     ['tcn_parkinson_s1_residual_2[
#  onv_4_sigm (Conv1D)                                                0][0]']
#
#  activation_20 (Activation)  (None, 4000, 64)             0         ['tcn_parkinson_s1_dilated_con
#                                                                     v_4_tanh[0][0]']
#
#  activation_21 (Activation)  (None, 4000, 64)             0         ['tcn_parkinson_s1_dilated_con
#                                                                     v_4_sigm[0][0]']
#
#  multiply_10 (Multiply)      (None, 4000, 64)             0         ['activation_20[0][0]',
#                                                                      'activation_21[0][0]']
#
#  tcn_parkinson_s1_dropout_4  (None, 4000, 64)             0         ['multiply_10[0][0]']
#   (SpatialDropout1D)
#
#  tcn_parkinson_s1_skip_4 (C  (None, 4000, 64)             4160      ['tcn_parkinson_s1_dropout_4[0
#  onv1D)                                                             ][0]']
#
#  tcn_parkinson_s1_residual_  (None, 4000, 64)             0         ['tcn_parkinson_s1_residual_2[
#  4 (Add)                                                            0][0]',
#                                                                      'tcn_parkinson_s1_skip_4[0][0
#                                                                     ]']
#
#  tcn_parkinson_s1_dilated_c  (None, 4000, 64)             12352     ['tcn_parkinson_s1_residual_4[
#  onv_8_tanh (Conv1D)                                                0][0]']
#
#  tcn_parkinson_s1_dilated_c  (None, 4000, 64)             12352     ['tcn_parkinson_s1_residual_4[
#  onv_8_sigm (Conv1D)                                                0][0]']
#
#  activation_22 (Activation)  (None, 4000, 64)             0         ['tcn_parkinson_s1_dilated_con
#                                                                     v_8_tanh[0][0]']
#
#  activation_23 (Activation)  (None, 4000, 64)             0         ['tcn_parkinson_s1_dilated_con
#                                                                     v_8_sigm[0][0]']
#
#  multiply_11 (Multiply)      (None, 4000, 64)             0         ['activation_22[0][0]',
#                                                                      'activation_23[0][0]']
#
#  tcn_parkinson_s1_dropout_8  (None, 4000, 64)             0         ['multiply_11[0][0]']
#   (SpatialDropout1D)
#
#  tcn_parkinson_s1_skip_8 (C  (None, 4000, 64)             4160      ['tcn_parkinson_s1_dropout_8[0
#  onv1D)                                                             ][0]']
#
#  tcn_parkinson_s1_residual_  (None, 4000, 64)             0         ['tcn_parkinson_s1_residual_4[
#  8 (Add)                                                            0][0]',
#                                                                      'tcn_parkinson_s1_skip_8[0][0
#                                                                     ]']
#
#  tcn_parkinson_s1_dilated_c  (None, 4000, 64)             12352     ['tcn_parkinson_s1_residual_8[
#  onv_16_tanh (Conv1D)                                               0][0]']
#
#  tcn_parkinson_s1_dilated_c  (None, 4000, 64)             12352     ['tcn_parkinson_s1_residual_8[
#  onv_16_sigm (Conv1D)                                               0][0]']
#
#  activation_24 (Activation)  (None, 4000, 64)             0         ['tcn_parkinson_s1_dilated_con
#                                                                     v_16_tanh[0][0]']
#
#  activation_25 (Activation)  (None, 4000, 64)             0         ['tcn_parkinson_s1_dilated_con
#                                                                     v_16_sigm[0][0]']
#
#  multiply_12 (Multiply)      (None, 4000, 64)             0         ['activation_24[0][0]',
#                                                                      'activation_25[0][0]']
#
#  tcn_parkinson_s1_dropout_1  (None, 4000, 64)             0         ['multiply_12[0][0]']
#  6 (SpatialDropout1D)
#
#  tcn_parkinson_s1_skip_16 (  (None, 4000, 64)             4160      ['tcn_parkinson_s1_dropout_16[
#  Conv1D)                                                            0][0]']
#
#  tcn_parkinson_s1_residual_  (None, 4000, 64)             0         ['tcn_parkinson_s1_residual_8[
#  16 (Add)                                                           0][0]',
#                                                                      'tcn_parkinson_s1_skip_16[0][
#                                                                     0]']
#
#  tcn_parkinson_s1_dilated_c  (None, 4000, 64)             12352     ['tcn_parkinson_s1_residual_16
#  onv_32_tanh (Conv1D)                                               [0][0]']
#
#  tcn_parkinson_s1_dilated_c  (None, 4000, 64)             12352     ['tcn_parkinson_s1_residual_16
#  onv_32_sigm (Conv1D)                                               [0][0]']
#
#  activation_26 (Activation)  (None, 4000, 64)             0         ['tcn_parkinson_s1_dilated_con
#                                                                     v_32_tanh[0][0]']
#
#  activation_27 (Activation)  (None, 4000, 64)             0         ['tcn_parkinson_s1_dilated_con
#                                                                     v_32_sigm[0][0]']
#
#  multiply_13 (Multiply)      (None, 4000, 64)             0         ['activation_26[0][0]',
#                                                                      'activation_27[0][0]']
#
#  tcn_parkinson_s1_dropout_3  (None, 4000, 64)             0         ['multiply_13[0][0]']
#  2 (SpatialDropout1D)
#
#  tcn_parkinson_s1_skip_32 (  (None, 4000, 64)             4160      ['tcn_parkinson_s1_dropout_32[
#  Conv1D)                                                            0][0]']
#
#  tcn_parkinson_s1_residual_  (None, 4000, 64)             0         ['tcn_parkinson_s1_residual_16
#  32 (Add)                                                           [0][0]',
#                                                                      'tcn_parkinson_s1_skip_32[0][
#                                                                     0]']
#
#  tcn_parkinson_s1_dilated_c  (None, 4000, 64)             12352     ['tcn_parkinson_s1_residual_32
#  onv_64_tanh (Conv1D)                                               [0][0]']
#
#  tcn_parkinson_s1_dilated_c  (None, 4000, 64)             12352     ['tcn_parkinson_s1_residual_32
#  onv_64_sigm (Conv1D)                                               [0][0]']
#
#  activation_28 (Activation)  (None, 4000, 64)             0         ['tcn_parkinson_s1_dilated_con
#                                                                     v_64_tanh[0][0]']
#
#  activation_29 (Activation)  (None, 4000, 64)             0         ['tcn_parkinson_s1_dilated_con
#                                                                     v_64_sigm[0][0]']
#
#  multiply_14 (Multiply)      (None, 4000, 64)             0         ['activation_28[0][0]',
#                                                                      'activation_29[0][0]']
#
#  tcn_parkinson_s1_dropout_6  (None, 4000, 64)             0         ['multiply_14[0][0]']
#  4 (SpatialDropout1D)
#
#  tcn_parkinson_s1_skip_64 (  (None, 4000, 64)             4160      ['tcn_parkinson_s1_dropout_64[
#  Conv1D)                                                            0][0]']
#
#  tcn_parkinson_s1_residual_  (None, 4000, 64)             0         ['tcn_parkinson_s1_residual_32
#  64 (Add)                                                           [0][0]',
#                                                                      'tcn_parkinson_s1_skip_64[0][
#                                                                     0]']
#
#  tcn_parkinson_s1_dilated_c  (None, 4000, 64)             12352     ['tcn_parkinson_s1_residual_64
#  onv_128_tanh (Conv1D)                                              [0][0]']
#
#  tcn_parkinson_s1_dilated_c  (None, 4000, 64)             12352     ['tcn_parkinson_s1_residual_64
#  onv_128_sigm (Conv1D)                                              [0][0]']
#
#  activation_30 (Activation)  (None, 4000, 64)             0         ['tcn_parkinson_s1_dilated_con
#                                                                     v_128_tanh[0][0]']
#
#  activation_31 (Activation)  (None, 4000, 64)             0         ['tcn_parkinson_s1_dilated_con
#                                                                     v_128_sigm[0][0]']
#
#  multiply_15 (Multiply)      (None, 4000, 64)             0         ['activation_30[0][0]',
#                                                                      'activation_31[0][0]']
#
#  tcn_parkinson_s1_dropout_1  (None, 4000, 64)             0         ['multiply_15[0][0]']
#  28 (SpatialDropout1D)
#
#  tcn_parkinson_s1_skip_128   (None, 4000, 64)             4160      ['tcn_parkinson_s1_dropout_128
#  (Conv1D)                                                           [0][0]']
#
#  tcn_parkinson_skip_sum (Ad  (None, 4000, 64)             0         ['tcn_parkinson_s0_skip_1[0][0
#  d)                                                                 ]',
#                                                                      'tcn_parkinson_s0_skip_2[0][0
#                                                                     ]',
#                                                                      'tcn_parkinson_s0_skip_4[0][0
#                                                                     ]',
#                                                                      'tcn_parkinson_s0_skip_8[0][0
#                                                                     ]',
#                                                                      'tcn_parkinson_s0_skip_16[0][
#                                                                     0]',
#                                                                      'tcn_parkinson_s0_skip_32[0][
#                                                                     0]',
#                                                                      'tcn_parkinson_s0_skip_64[0][
#                                                                     0]',
#                                                                      'tcn_parkinson_s0_skip_128[0]
#                                                                     [0]',
#                                                                      'tcn_parkinson_s1_skip_1[0][0
#                                                                     ]',
#                                                                      'tcn_parkinson_s1_skip_2[0][0
#                                                                     ]',
#                                                                      'tcn_parkinson_s1_skip_4[0][0
#                                                                     ]',
#                                                                      'tcn_parkinson_s1_skip_8[0][0
#                                                                     ]',
#                                                                      'tcn_parkinson_s1_skip_16[0][
#                                                                     0]',
#                                                                      'tcn_parkinson_s1_skip_32[0][
#                                                                     0]',
#                                                                      'tcn_parkinson_s1_skip_64[0][
#                                                                     0]',
#                                                                      'tcn_parkinson_s1_skip_128[0]
#                                                                     [0]']
#
#  tcn_parkinson_post_relu (A  (None, 4000, 64)             0         ['tcn_parkinson_skip_sum[0][0]
#  ctivation)                                                         ']
#
#  global_avg_pool (GlobalAve  (None, 64)                   0         ['tcn_parkinson_post_relu[0][0
#  ragePooling1D)                                                     ]']
#
#  global_max_pool (GlobalMax  (None, 64)                   0         ['tcn_parkinson_post_relu[0][0
#  Pooling1D)                                                         ]']
#
#  pool_concat (Concatenate)   (None, 128)                  0         ['global_avg_pool[0][0]',
#                                                                      'global_max_pool[0][0]']
#
#  dense_hidden (Dense)        (None, 32)                   4128      ['pool_concat[0][0]']
#
#  dense_dropout (Dropout)     (None, 32)                   0         ['dense_hidden[0][0]']
#
#  output (Dense)              (None, 2)                    66        ['dense_dropout[0][0]']
#
# ==================================================================================================
# Total params: 466146 (1.78 MB)
# Trainable params: 466146 (1.78 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# ## 4. Compilar el Modelo

# %%
clf.model.compile(
    optimizer = OPTIMIZER,
    loss      = tf.keras.losses.CategoricalCrossentropy(),
    metrics   = ['accuracy'],
)
print("Modelo compilado ✓")
# Out:
# Modelo compilado ✓

# %% [markdown]
# ## 5. Entrenamiento
#
# Se usan dos callbacks estándar:
# - **EarlyStopping**: para si la val_loss no mejora durante `patience` epochs
# - **ReduceLROnPlateau**: reduce el learning rate × 0.5 si no mejora en 5 epochs

# %%
# callbacks = [
#     EarlyStopping(
#         monitor='val_loss',
#         patience=50,
#         restore_best_weights=True,
#         verbose=1,
#     ),
#     ReduceLROnPlateau(
#         monitor='val_loss',
#         factor=0.5,
#         patience=5,
#         min_lr=1e-6,
#         verbose=1,
#     ),
# ]


callbacks = [
    EarlyStopping(
        monitor='val_accuracy',     # 1. Cambia esto para vigilar la accuracy
        mode='max',                 # 2. Añade esto para indicarle que busque el valor MÁXIMO
        patience=15,                # Puedes subir un poco la paciencia si fluctúa mucho
        restore_best_weights=True,
        verbose=1,
    ),
    ReduceLROnPlateau(
        monitor='val_loss',         # Este puedes dejarlo en val_loss o cambiarlo a val_accuracy
        factor=0.5,
        patience=5,
        min_lr=1e-6,
        verbose=1,
    ),
]

history = clf.model.fit(
    X_train, y_train,
    validation_data = (X_val, y_val),
    epochs          = EPOCHS,
    batch_size      = BATCH_SIZE,
    shuffle         = True,
    callbacks       = callbacks,
)
# Out:
# Epoch 1/50
# 2026-05-09 10:25:17.127560: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8902
# 2026-05-09 10:25:20.249850: I external/local_xla/xla/service/service.cc:168] XLA service 0x14fd0087b040 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2026-05-09 10:25:20.249894: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA A100-PCIE-40GB, Compute Capability 8.0
# 2026-05-09 10:25:20.324408: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1778322320.629394    4072 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 12/12 [==============================] - 22s 312ms/step - loss: 0.7576 - accuracy: 0.5250 - val_loss: 0.6938 - val_accuracy: 0.5750 - lr: 0.0010
# Epoch 2/50
# 12/12 [==============================] - 1s 85ms/step - loss: 0.6902 - accuracy: 0.5750 - val_loss: 0.7367 - val_accuracy: 0.5417 - lr: 0.0010
# Epoch 3/50
# 12/12 [==============================] - 1s 86ms/step - loss: 0.6601 - accuracy: 0.6111 - val_loss: 0.7866 - val_accuracy: 0.4750 - lr: 0.0010
# Epoch 4/50
# 12/12 [==============================] - 1s 85ms/step - loss: 0.6926 - accuracy: 0.5833 - val_loss: 0.7071 - val_accuracy: 0.5000 - lr: 0.0010
# Epoch 5/50
# 12/12 [==============================] - 1s 85ms/step - loss: 0.6489 - accuracy: 0.6306 - val_loss: 0.7003 - val_accuracy: 0.5167 - lr: 0.0010
# Epoch 6/50
# 11/12 [==========================>...] - ETA: 0s - loss: 0.6380 - accuracy: 0.6136
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 12/12 [==============================] - 1s 86ms/step - loss: 0.6377 - accuracy: 0.6139 - val_loss: 0.7192 - val_accuracy: 0.5500 - lr: 0.0010
# Epoch 7/50
# 12/12 [==============================] - 1s 85ms/step - loss: 0.5825 - accuracy: 0.6833 - val_loss: 0.7660 - val_accuracy: 0.5250 - lr: 5.0000e-04
# Epoch 8/50
# 12/12 [==============================] - 1s 85ms/step - loss: 0.5689 - accuracy: 0.6944 - val_loss: 0.7597 - val_accuracy: 0.4917 - lr: 5.0000e-04
# Epoch 9/50
# 12/12 [==============================] - 1s 84ms/step - loss: 0.5424 - accuracy: 0.7056 - val_loss: 0.7601 - val_accuracy: 0.5167 - lr: 5.0000e-04
# Epoch 10/50
# 12/12 [==============================] - 1s 85ms/step - loss: 0.5224 - accuracy: 0.7556 - val_loss: 0.7889 - val_accuracy: 0.5250 - lr: 5.0000e-04
# Epoch 11/50
# 11/12 [==========================>...] - ETA: 0s - loss: 0.5013 - accuracy: 0.7500
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 12/12 [==============================] - 1s 85ms/step - loss: 0.5000 - accuracy: 0.7500 - val_loss: 0.8042 - val_accuracy: 0.5667 - lr: 5.0000e-04
# Epoch 12/50
# 12/12 [==============================] - 1s 85ms/step - loss: 0.4249 - accuracy: 0.8139 - val_loss: 0.7990 - val_accuracy: 0.5583 - lr: 2.5000e-04
# Epoch 13/50
# 12/12 [==============================] - 1s 87ms/step - loss: 0.4226 - accuracy: 0.8056 - val_loss: 0.8124 - val_accuracy: 0.5833 - lr: 2.5000e-04
# Epoch 14/50
# 12/12 [==============================] - 1s 88ms/step - loss: 0.3886 - accuracy: 0.8194 - val_loss: 0.7839 - val_accuracy: 0.5917 - lr: 2.5000e-04
# Epoch 15/50
# 12/12 [==============================] - 1s 87ms/step - loss: 0.3673 - accuracy: 0.8528 - val_loss: 0.7488 - val_accuracy: 0.6167 - lr: 2.5000e-04
# Epoch 16/50
# 11/12 [==========================>...] - ETA: 0s - loss: 0.3646 - accuracy: 0.8381
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 12/12 [==============================] - 1s 87ms/step - loss: 0.3707 - accuracy: 0.8333 - val_loss: 0.7348 - val_accuracy: 0.6250 - lr: 2.5000e-04
# Epoch 17/50
# 12/12 [==============================] - 1s 88ms/step - loss: 0.3797 - accuracy: 0.8278 - val_loss: 0.7254 - val_accuracy: 0.6333 - lr: 1.2500e-04
# Epoch 18/50
# 12/12 [==============================] - 1s 84ms/step - loss: 0.3245 - accuracy: 0.8472 - val_loss: 0.7339 - val_accuracy: 0.6250 - lr: 1.2500e-04
# Epoch 19/50
# 12/12 [==============================] - 1s 85ms/step - loss: 0.3242 - accuracy: 0.8694 - val_loss: 0.7350 - val_accuracy: 0.6250 - lr: 1.2500e-04
# Epoch 20/50
# 12/12 [==============================] - 1s 85ms/step - loss: 0.3522 - accuracy: 0.8361 - val_loss: 0.7519 - val_accuracy: 0.6250 - lr: 1.2500e-04
# Epoch 21/50
# 11/12 [==========================>...] - ETA: 0s - loss: 0.3159 - accuracy: 0.8835
# Epoch 21: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 12/12 [==============================] - 1s 85ms/step - loss: 0.3145 - accuracy: 0.8861 - val_loss: 0.7482 - val_accuracy: 0.6167 - lr: 1.2500e-04
# Epoch 22/50
# 12/12 [==============================] - 1s 84ms/step - loss: 0.2850 - accuracy: 0.8806 - val_loss: 0.7649 - val_accuracy: 0.6000 - lr: 6.2500e-05
# Epoch 23/50
# 12/12 [==============================] - 1s 84ms/step - loss: 0.2509 - accuracy: 0.9083 - val_loss: 0.7752 - val_accuracy: 0.6000 - lr: 6.2500e-05
# Epoch 24/50
# 12/12 [==============================] - 1s 85ms/step - loss: 0.3047 - accuracy: 0.8750 - val_loss: 0.7828 - val_accuracy: 0.6000 - lr: 6.2500e-05
# Epoch 25/50
# 12/12 [==============================] - 1s 85ms/step - loss: 0.2694 - accuracy: 0.9056 - val_loss: 0.7843 - val_accuracy: 0.6083 - lr: 6.2500e-05
# Epoch 26/50
# 11/12 [==========================>...] - ETA: 0s - loss: 0.2913 - accuracy: 0.8977
# Epoch 26: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 12/12 [==============================] - 1s 85ms/step - loss: 0.2916 - accuracy: 0.8972 - val_loss: 0.7774 - val_accuracy: 0.6000 - lr: 6.2500e-05
# Epoch 27/50
# 12/12 [==============================] - 1s 84ms/step - loss: 0.2592 - accuracy: 0.9083 - val_loss: 0.7897 - val_accuracy: 0.6167 - lr: 3.1250e-05
# Epoch 28/50
# 12/12 [==============================] - 1s 85ms/step - loss: 0.2673 - accuracy: 0.8917 - val_loss: 0.7849 - val_accuracy: 0.6000 - lr: 3.1250e-05
# Epoch 29/50
# 12/12 [==============================] - 1s 85ms/step - loss: 0.2624 - accuracy: 0.9167 - val_loss: 0.7931 - val_accuracy: 0.5917 - lr: 3.1250e-05
# Epoch 30/50
# 12/12 [==============================] - 1s 85ms/step - loss: 0.2762 - accuracy: 0.8972 - val_loss: 0.7919 - val_accuracy: 0.5917 - lr: 3.1250e-05
# Epoch 31/50
# 11/12 [==========================>...] - ETA: 0s - loss: 0.2677 - accuracy: 0.9062
# Epoch 31: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 12/12 [==============================] - 1s 85ms/step - loss: 0.2734 - accuracy: 0.9000 - val_loss: 0.7906 - val_accuracy: 0.6083 - lr: 3.1250e-05
# Epoch 32/50
# 11/12 [==========================>...] - ETA: 0s - loss: 0.2737 - accuracy: 0.8977Restoring model weights from the end of the best epoch: 17.
# 12/12 [==============================] - 1s 89ms/step - loss: 0.2724 - accuracy: 0.8972 - val_loss: 0.7889 - val_accuracy: 0.6000 - lr: 1.5625e-05
# Epoch 32: early stopping

# %% [markdown]
# ## 6. Curvas de Aprendizaje

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 4))

# Pérdida
axes[0].plot(history.history['loss'],     label='Train loss')
axes[0].plot(history.history['val_loss'], label='Val loss')
axes[0].set_title('Loss')
axes[0].set_xlabel('Epoch')
axes[0].legend()
axes[0].grid(True, alpha=0.3)

# Accuracy
axes[1].plot(history.history['accuracy'],     label='Train acc')
axes[1].plot(history.history['val_accuracy'], label='Val acc')
axes[1].set_title('Accuracy')
axes[1].set_xlabel('Epoch')
axes[1].legend()
axes[1].grid(True, alpha=0.3)

plt.suptitle(f'TCN — {DATASET_NAME} — Fold {FOLD_IDX+1}/{K}', fontsize=13)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Evaluación en Validation

# %% [markdown]
# ## 7. Evaluación en Test

# %%
# Predicciones
y_pred_proba = clf.predict(X_test, batch_size=BATCH_SIZE)  # shape (N, 2)
y_pred       = np.argmax(y_pred_proba, axis=1)             # clase predicha
y_true       = y_test_raw                                  # entero (0/1)

# Métricas
acc = accuracy_score(y_true, y_pred)
roc = roc_auc_score(y_true, y_pred_proba[:, 1])

print(f"{'='*50}")
print(f" RESULTADOS — Fold {FOLD_IDX+1}/{K}")
print(f"{'='*50}")
print(f"  Accuracy : {acc:.4f}")
print(f"  ROC-AUC  : {roc:.4f}")
print()
print(classification_report(y_true, y_pred, target_names=['Control', 'Patológicas']))
# Out:
# ==================================================
#  RESULTADOS — Fold 5/5
# ==================================================
#   Accuracy : 0.6333
#   ROC-AUC  : 0.6958
#
#               precision    recall  f1-score   support
#
#      Control       0.63      0.63      0.63        60
#  Patológicas       0.63      0.63      0.63        60
#
#     accuracy                           0.63       120
#    macro avg       0.63      0.63      0.63       120
# weighted avg       0.63      0.63      0.63       120

# %%
# ── DIAGNÓSTICO: comparar métrica Keras vs sklearn en VALIDACIÓN ──────
y_val_pred_proba = clf.predict(X_val, batch_size=BATCH_SIZE)
y_val_pred = np.argmax(y_val_pred_proba, axis=1)

acc_val_sklearn = accuracy_score(y_val_raw, y_val_pred)
print(f"Val accuracy (sklearn):          {acc_val_sklearn:.4f}")
print(f"Val accuracy (Keras en training): ver logs arriba")
print(f"→ Si difieren mucho, hay un bug de métrica en Keras 3")
# Out:
# Val accuracy (sklearn):          0.6333
# Val accuracy (Keras en training): ver logs arriba
# → Si difieren mucho, hay un bug de métrica en Keras 3

# %% [markdown]
# ## 8. Matriz de Confusión y Curva ROC

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Confusion Matrix
cm   = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(cm, display_labels=['Control', 'Patológicas'])
disp.plot(ax=axes[0], cmap='Blues')
axes[0].set_title(f'Confusion Matrix (Fold {FOLD_IDX+1})')

# ROC Curve
RocCurveDisplay.from_predictions(
    y_true, y_pred_proba[:, 1],
    name='TCN',
    ax=axes[1],
)
axes[1].set_title(f'ROC Curve (AUC={roc:.3f})')
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 9. (Opcional) K-Fold Completo
#
# Descomenta para entrenar sobre todos los folds y obtener métricas promedio.
# **⚠ Puede tardar bastante dependiendo de la duración del audio y el hardware.**

# %%
# all_accs, all_aucs = [], []
#
# for k in range(K):
#     print(f"\n{'='*60}")
#     print(f" FOLD {k+1}/{K}")
#     print(f"{'='*60}")
#
#     fd = folds[k]
#     X_tr, y_tr_raw, X_v, y_v_raw, X_te, y_te_raw = load_fold_data(
#         fd, DATA_DIR, TARGET_SR, TARGET_SAMPLES
#     )
#     y_tr = to_categorical(y_tr_raw, NUM_CLASSES)
#     y_v  = to_categorical(y_v_raw,  NUM_CLASSES)
#
#     # Modelo nuevo por fold (pesos frescos)
#     clf_k = TCNClassifier(
#         input_shape  = (TARGET_SAMPLES,),
#         n_classes    = NUM_CLASSES,
#         nb_filters   = NB_FILTERS,
#         kernel_size  = KERNEL_SIZE,
#         dilations    = DILATIONS,
#         nb_stacks    = NB_STACKS,
#         dropout_rate = DROPOUT_RATE,
#         dense_units  = DENSE_UNITS,
#     )
#     clf_k.model.compile(
#         optimizer = OPTIMIZER,
#         loss      = tf.keras.losses.CategoricalCrossentropy(),
#         metrics   = ['accuracy'],
#     )
#     clf_k.model.fit(
#         X_tr, y_tr,
#         validation_data = (X_v, y_v),
#         epochs     = EPOCHS,
#         batch_size = BATCH_SIZE,
#         shuffle    = True,
#         callbacks  = callbacks,
#         verbose    = 0,
#     )
#
#     yp_proba = clf_k.predict(X_te)
#     yp       = np.argmax(yp_proba, axis=1)
#     acc_k    = accuracy_score(y_te_raw, yp)
#     auc_k    = roc_auc_score(y_te_raw, yp_proba[:, 1])
#     all_accs.append(acc_k)
#     all_aucs.append(auc_k)
#     print(f"  → Fold {k+1}: Acc={acc_k:.4f}  AUC={auc_k:.4f}")
#
# print(f"\n{'='*60}")
# print(f" RESULTADOS K-FOLD PROMEDIO")
# print(f"{'='*60}")
# print(f"  Accuracy: {np.mean(all_accs):.4f} ± {np.std(all_accs):.4f}")
# print(f"  ROC-AUC:  {np.mean(all_aucs):.4f} ± {np.std(all_aucs):.4f}")
