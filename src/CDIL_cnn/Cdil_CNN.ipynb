# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !python "/content/drive/MyDrive/TFM-Data-Science/src/CDIL_cnn/train_parkinson_folds.py" --dataset neurovoz
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# ________________________________________________________________________________
# 100% 1/1 [00:00<00:00, 10.61it/s]
# Test num: 92 — Test loss: 0.6888 — Test accuracy: 56.52 — Time: 0.1s
# ________________________________________________________________________________________________________________________
# ★ Best val:51.52  test:56.52  (epoch 9)
# 100% 2/2 [00:01<00:00,  1.48it/s]
# Epoch 10 | Train loss:0.6907 acc:57.43 | Time:1.4s
# 100% 1/1 [00:00<00:00, 15.08it/s]
# Val num: 66 — Val loss: 0.6937 — Val accuracy: 50.00 — Time: 0.1s
# ________________________________________________________________________________
# 100% 2/2 [00:01<00:00,  1.46it/s]
# Epoch 11 | Train loss:0.6875 acc:57.43 | Time:1.4s
# 100% 1/1 [00:00<00:00, 15.23it/s]
# Val num: 66 — Val loss: 0.6954 — Val accuracy: 50.00 — Time: 0.1s
# ________________________________________________________________________________
# ...
