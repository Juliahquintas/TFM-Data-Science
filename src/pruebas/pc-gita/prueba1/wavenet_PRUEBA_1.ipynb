# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import torch
torch.cuda.is_available()
# Out:
# False

# %%
import os
import sys
import torch

print("="*50)
# 1. ¿Qué hardware está usando PyTorch?
if torch.cuda.is_available():
    print(f" Disp. Gráfico:  CONECTADO A GPU ({torch.cuda.get_device_name(0)})")
else:
    print(" Disp. Gráfico:  No hay GPU disponible (Estás usando CPU)")

# 2. ¿Es el servidor de Google Colab o tu PC local?
# Colab siempre tiene la variable de entorno 'COLAB_GPU' o la carpeta '/content'
if 'google.colab' in sys.modules or os.path.exists('/content'):
    print(" Servidor:       Conectado a GOOGLE COLAB (Nube)")
else:
    print(" Servidor:       Conectado a tu MÁQUINA LOCAL")

# 3. ¿En qué carpeta del disco estás metido ahora mismo?
print(f" Ruta actual:    {os.getcwd()}")
print("="*50)
# Out:
# ...
#  Disp. Gráfico:  No hay GPU disponible (Estás usando CPU)
#  Servidor:       Conectado a GOOGLE COLAB (Nube)
#  Ruta actual:    /content
# ...

# %%
# !ls -la
# Out:
# total 16
# drwxr-xr-x 1 root root 4096 May 12 13:29 .
# drwxr-xr-x 1 root root 4096 May 20 11:19 ..
# drwxr-xr-x 4 root root 4096 May 12 13:29 .config
# drwxr-xr-x 1 root root 4096 May 12 13:29 sample_data

# %%
# !python TFM-DATA-SCIENCE/src/pruebas/pc-gita/prueba1/wavenet_model.py
# Out:
# python3: can't open file '/content/TFM-DATA-SCIENCE/src/pruebas/pc-gita/prueba1/wavenet_model.py': [Errno 2] No such file or directory

# %%
# !python src/pruebas/pc-gita/prueba1/wavenet_model.py
# Out:
# python3: can't open file '/content/src/pruebas/pc-gita/prueba1/wavenet_model.py': [Errno 2] No such file or directory

# %%
ls 'c:\Users\julia\LOCAL_JULIA\PROYECTOS GIT\TFM-Data-Science\src\pruebas\pc-gita\prueba1'
# Out:
# ls: cannot access 'c:\Users\julia\LOCAL_JULIA\PROYECTOS GIT\TFM-Data-Science\src\pruebas\pc-gita\prueba1': No such file or directory

# %%
# !python 'c:\Users\julia\LOCAL_JULIA\PROYECTOS GIT\TFM-Data-Science\src\pruebas\pc-gita\prueba1wavenet_model.py'
# Out:
# python3: can't open file '/content/wavenet_model.py': [Errno 2] No such file or directory

# %%
# !python "/content/drive/MyDrive/TFM Parkinson/experimentos nuevos/wavenet/wavenet_model.py"
# Out:
# ...
#   Experimento : Flexible_C1_G1_D1 (Estructura Flexible)
#   Dataset     : pc-gita
#   Epochs      : 200  |  LR: 0.001  |  Batch: 32
#   NHID=32, KS=3, Dropout=0.0
#   Config      : Causal=True | Gated=True | Deformable=True
#   Device      : cuda
# ...
#
# Muestras por audio   : 10781  (0.489s @ 22050Hz)
# Capas convolucionales: 8
# Parámetros del modelo: 66,373
#
# ...
#   FOLD 1 — COMPROBACIÓN RÁPIDA
# ...
#
#   Train: 432 | Val: 48 | Test: 120
#     Cargados: 432 audios (Control=213, Parkinson=219)
#     Cargados: 48 audios (Control=27, Parkinson=21)
#     Cargados: 120 audios (Control=60, Parkinson=60)
#     Epoch [  1/200] Train: loss=0.7081, acc=49.3%  |  Val: loss=0.6886, acc=56.2%  ← best
#     Epoch [ 10/200] Train: loss=0.6646, acc=59.3%  |  Val: loss=0.6660, acc=54.2%
#     Epoch [ 20/200] Train: loss=0.5476, acc=72.5%  |  Val: loss=0.6214, acc=66.7%
#     Epoch [ 30/200] Train: loss=0.4000, acc=84.7%  |  Val: loss=0.6176, acc=72.9%
# ...
