# %%
#================
# ORIGINAL
# ================
# DATASET              = 'pc-gita'   # 'pc-gita' o 'neurovoz'
# NHID                 = 32
# KERNEL_SIZE          = 3
# DROPOUT              = 0.0         # 0.0 para replicar exactamente a Marta Rey

# # --- INTERRUPTORES DE INNOVACIÓN ---
# CAUSAL               = True        # True: Causal (WaveNet) | False: Circular (CDIL)
# GATED                = True        # True: Tanh * Sigmoid | False: ReLU Convencional
# DEFORMABLE           = False        # True: Activa offsets deformables | False: Convolución rígida

# BATCH_SIZE           = 32
# N_EPOCHS             = 200
# LR                   = 1e-3
# WEIGHT_DECAY         = 1e-3
# EARLY_STOP_PATIENCE  = 30
# VAL_RATIO            = 0.10
# SEED                 = 42
# K_FOLDS              = 5

# #================
# # ESTA PRUEBA
# # ================
# DROPOUT = 0.4
# NHID = 16  # Baja de 32 a 16
# WEIGHT_DECAY = 1e-2  # Súbelo de 1e-3 a 1e-2

# %%
ls '/kaggle/input/datasets/juliahernndezquintas/pcgita-prueba0/wavenet_model.py'
# Out:
# False

# %%
# !python "/kaggle/input/datasets/juliahernndezquintas/pcgita-prueba0/wavenet_model.py"
# Out:
# Mounted at /content/drive
